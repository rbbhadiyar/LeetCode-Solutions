# %% [markdown]
# 2. Given a positive integer, find out the sum of all
# integers from 1 up to this number.

# %%
#Finding sum of integers from 1 upto the given integer
# a = given positive integer
a=50
#initiating the sum variable
sum1=0
#iterating the integers in range(1,a+1)
for i in range(1,a+1):
    
    #adding i in sum1 and updating it
    sum1+=i
print("Sum of integers from 1 upto the given integer is:",sum1)

# %%
class Solution(object):
    def reverse(x):
        y= str(x)
        if y[0]!="-":
            y = (y[::-1])
        else:
            y = "-"+(y[:0:-1])
        y = int(y)
        if y>=((-2)**31) and y<=((2**31)-1):
            print(y)
            return(y)
        else:
            print(0)
            return(0)
    reverse(1534236469)
# Out:
# 0

# %%
import numpy as np
import matplotlib.pyplot as plt

# Sample data (independent variable x, dependent variable y)
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# Calculating the means of x and y
x_mean = np.mean(x)
y_mean = np.mean(y)

# Calculating the slope (m) and y-intercept (c) for y = mx + c
numerator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean) ** 2)
m = numerator / denominator
c = y_mean - m * x_mean

print(f"Slope (m): {m}")
print(f"Intercept (c): {c}")

# Predicting y values
y_pred = m * x + c

# Plotting the results
plt.scatter(x, y, color="blue", label="Original Data")
plt.plot(x, y_pred, color="red", label="Fitted Line")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %%
import java.io.File;
import java.io.IOException;
public class FileHandling {

    public static void main(String[] args) {
        try{
            File file = new File("C:\Users\rbbha\OneDrive\Desktop\Python files\DHP/abcd.txt");
            if (file.createNewFile()){
                System.out.println("File is created:"+ file.getName());
                
            }else{
                System.out.println("File already exits");
            }


        }
        catch(IOException e){
            e.printStackTrace();

        }
    }
    public static void main(String[] args) {
        try{
            fileWriter writer = new FileWriter("C:\Users\rbbha\OneDrive\Desktop\Python files\DHP/abcd.txt")
            writer.write("students are the brand ambasder of Sitare University")
            writer.close()
        }
        catch(IOException e){
            e.printStackTrace();

        }
    }
    
}
